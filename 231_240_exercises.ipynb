# %% [markdown]
# <a href="https://colab.research.google.com/github/Krzesimir13/Udemy_DS/blob/main/231_240_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Science Bootcamp
#
# ### Spis treści:
# * [Import biblioteki](#0)
# * [Ćwiczenie 231](#1)
# * [Ćwiczenie 232](#2)
# * [Ćwiczenie 233](#3)
# * [Ćwiczenie 234](#4)
# * [Ćwiczenie 235](#5)
# * [Ćwiczenie 236](#6)
# * [Ćwiczenie 237](#7)
# * [Ćwiczenie 238](#8)
# * [Ćwiczenie 239](#9)
# * [Ćwiczenie 240](#10)

# %% [markdown]
# ### <a name='0'></a>Import biblioteki

# %%
import numpy as np
import pandas as pd

np.__version__
# Out:
# '2.0.2'

# %% [markdown]
# ### <a name='1'></a> Ćwiczenie 231
# Zaimportuj bibliotekę _tensorflow_ w wersji 2.x.

# %%
# %tensorflow_version 2.x
import tensorflow as tf

tf.__version__
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# '2.19.0'

# %% [markdown]
# Załaduj dane Fashion MNIST wykorzystując bibliotekę _tensorflow_. Odpowiednio zbiór treningowy (_X\_train_, _y\_train_) oraz testowy (_X\_test_, _y\_test_).

# %%
import tensorflow as tf
from tensorflow.keras.datasets.mnist import load_data


(X_train, y_train), (X_test, y_test) = load_data()

# %% [markdown]
# Sprawdź rozmiar zbiorów treningowych i testowych.

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# ### <a name='2'></a> Ćwiczenie 232
# Wykorzytując bibliotekę _matplotlib_ wyświetl obraz ze zbioru treningowego z indeksem 40.

# %%
import matplotlib.pyplot as plt


plt.imshow(X_train[40], cmap='gray_r')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))

# %% [markdown]
# Wyświetl numer klasy dla próbki ze zbioru treningowego z ineksem 40.

# %%
y_train[40]
# Out:
# np.uint8(1)

# %% [markdown]
# ### <a name='3'></a> Ćwiczenie 233
# Wystandaryzuj dane. Podziel wartości tablic _X\_train_ oraz _X\_test_ przez wartość 255.0.

# %%
X_train = X_train / 255
y_train = y_train / 255

# %% [markdown]
# ### <a name='4'></a> Ćwiczenie 234
# Zaimportuj klasę _Sequential_ z biblioteki _tensorflow_ wykorzystując pakiet _keras_.

# %%
from tensorflow.keras.models import Sequential

# %% [markdown]
# Zaimportuj warstwy _Flatten_ oraz _Dense_ z biblioteki _tensorflow_ wykorzystując pakiet _keras_.

# %%
from tensorflow.keras.layers import Flatten, Dense

# %% [markdown]
# ### <a name='5'></a> Ćwiczenie 235
# Zbuduj model klasy _Sequential_.

# %%
model = Sequential()

# %% [markdown]
# Dodaj pierwszą warstwę typu _Flatten_ wraz z odpowiednio dobranym parametrem _input_shape_.

# %%
model.add(Flatten(input_shape=(28, 28)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# Dodaj kolejną warstwę typu _Dense_ z 128 neuronami i funkcją aktywacji _relu_.

# %%
model.add(Dense(units=128, activation='relu'))

# %% [markdown]
# Dodaj ostatnią warstwę typu _Dense_ z 10 neuronami i funkcją aktywacji _softmax_.

# %%
model.add(Dense(units=10, activation='softmax'))

# %% [markdown]
# Wyświetl podsumowanie modelu.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### <a name='6'></a> Ćwiczenie 236
# Skompiluj model. Wykorzystaj optymalizator _rmsprop_, funkcję straty _sparse_categorical_crossentropy_ oraz metrykę _accuracy_.

# %%
model.compile(optimizer='rmsprop',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### <a name='7'></a> Ćwiczenie 237
# Dopasuj model do danych treningowych, ustawiając 10 epok oraz podział na zbiór walidacyjny wynoszący 0.2.

# %%
model.fit(X_train, y_train, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9440 - loss: 0.4169 - val_accuracy: 0.9413 - val_loss: 0.5783
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9545 - loss: 0.3578 - val_accuracy: 0.9391 - val_loss: 0.6802
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9584 - loss: 0.3578 - val_accuracy: 0.9488 - val_loss: 0.5890
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9628 - loss: 0.2925 - val_accuracy: 0.9513 - val_loss: 0.6874
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9669 - loss: 0.2553 - val_accuracy: 0.9541 - val_loss: 0.5896
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9705 - loss: 0.2365 - val_accuracy: 0.9538 - val_loss: 0.5215
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9707 - loss: 0.2147 - val_accuracy: 0.9582 - val_loss: 0.6238
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9750 - loss: 0.2103 - val_accuracy: 0.9612 - val_loss: 0.6010
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9759 - loss: 0.1916 - val_accuracy: 0.9588 - val_loss: 0.6324
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9781 - loss: 0.1830 - val_accuracy: 0.9584 - val_loss: 0.6867

# %% [markdown]
# ### <a name='8'></a> Ćwiczenie 238
# Dokonaj predykcji modelu na podstawie danych testowych.

# %%
model.predict(X_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 9.9999994e-01,
#         0.0000000e+00, 0.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 9.9999994e-01, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00],
#        [2.9344324e-32, 9.9999994e-01, 1.8494371e-34, ..., 4.9023304e-29,
#         3.4190191e-32, 1.0113292e-36],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 2.3806525e-22,
#         9.9691526e-15, 6.3831874e-16],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 1.8130965e-21,
#         3.7365766e-35, 1.9506991e-34],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, ..., 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)

# %% [markdown]
# Zbuduj macierz konfuzji (macierz pomyłek).

# %%
from sklearn.metrics import confusion_matrix

y_pred = np.argmax(model.predict(X_test), axis=1)
confusion_matrix(y_test, y_pred)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# array([[ 971,    0,    0,    2,    0,    1,    3,    0,    2,    1],
#        [   0, 1106,    3,    4,    2,    4,    5,    0,   11,    0],
#        [   5,    3,  984,   12,    2,    0,    5,    6,   15,    0],
#        [   2,    0,    4,  984,    1,    5,    0,    2,    5,    7],
#        [   3,    1,    2,    1,  945,    0,    6,    4,    5,   15],
#        [   6,    0,    0,   41,    0,  828,    7,    3,    5,    2],
#        [  10,    2,    1,    1,    4,    6,  927,    0,    7,    0],
#        [   0,    6,    7,   13,    2,    2,    1,  980,    4,   13],
#        [  10,    0,    6,   21,    3,   11,    7,    3,  903,   10],
#        [   9,    4,    1,   11,   12,    3,    0,    6,    9,  954]])

# %% [markdown]
# ### <a name='9'></a> Ćwiczenie 239
# Zbuduj obiekt pandas _DataFrame_ zawierający predykcje modelu. Nadaj nazwę kolumny _prediction_ i przypisz do zmiennej _results_.

# %%
import pandas as pd

results = pd.DataFrame(y_pred, columns=['prediction'])

results.head()
# Out:
#    prediction
# 0           7
# 1           2
# 2           1
# 3           0
# 4           4

# %% [markdown]
# Przypisz nową kolumnę z wartościami ze zmiennej _y\_test_ i nazwij ją _y\_test_.

# %%
results['y_test'] = y_test

# %% [markdown]
# Przypisz nową kolumnę o nazwie _is_misclassified_, która zwróci 1, gdy próbki zostaną błędnie sklasyfikowane, w przeciwnym przypadku 0.

# %%
results['is_misclassified'] = (results['y_test'] == results['prediction']).astype(int)
results['is_misclassified'].value_counts()
# Out:
# is_misclassified
# 1    9582
# 0     418
# Name: count, dtype: int64

# %% [markdown]
# ### <a name='10'></a> Ćwiczenie 240
# Zapisz obiekt _results_ do pliku _results.csv_.

# %%
results.to_csv('results.csv')

# %%
# !head results.csv
# Out:
# ,prediction,y_test,is_misclassified
# 0,7,7,1
# 1,2,2,1
# 2,1,1,1
# 3,0,0,1
# 4,4,4,1
# 5,1,1,1
# 6,4,4,1
# 7,9,9,1
# 8,5,5,1
